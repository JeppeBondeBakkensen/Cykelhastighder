# %%
from data_cleaning import clean_dataset, metadata
import pandas as pd
from plotting import plot_fordelings_af_hastigheder
import pandas as pd
from importlib import reload
import data_cleaning
import plotting
import config

# Load and clean dataset 
df = pd.read_csv("Vermlandsgade_cykelhastigheder.csv")
df = clean_dataset(df)
metadata = metadata(df)

# %%
# Fordeling af hastigheder
plot_fordelings_af_hastigheder(df, metadata)

# %%
import pandas as pd
from importlib import reload

import data_cleaning
import plotting
import config

# reload modules in case you just edited them (Jupyter-friendly)
reload(data_cleaning)
reload(plotting)
reload(config)

# Load and clean
df = pd.read_csv("Vermlandsgade_cykelhastigheder.csv")
df = data_cleaning.clean_dataset(df)

# Plot
fig, axes = plotting.plot_scatter_lowess_panels(df, config.FREQS)
